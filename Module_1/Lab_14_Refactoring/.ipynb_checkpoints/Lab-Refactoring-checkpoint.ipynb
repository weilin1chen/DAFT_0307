# %%
def print_board():
    row1 = "| {} | {} | {} |".format(board[0], board[1], board[2])
    row2 = "| {} | {} | {} |".format(board[3], board[4], board[5])
    row3 = "| {} | {} | {} |".format(board[6], board[7], board[8])
    print()
    print(row1)
    print(row2)
    print(row3)
    print()
    
def player_move(icon):
    if AI_Human == 2:
        if icon == "X":
            number = 1
        
        elif icon == "O":
            number = 2
        print("Your turn player {}".format(number))
        valid_choice = False
        
        while not valid_choice:
            try:
                choice = int(input("Enter your move (1-9): ").strip())
                if not (1 <= choice <= 9):
                    raise ValueError()
                valid_choice = True
            
            except ValueError:
                print("Please enter a valid integer between 1 and 9 to continue playing.")

        if board[choice - 1] == " ":
            board[choice - 1] = icon

        else:
            print()
            print("That space is taken!")
            player_move(icon)
    
    elif AI_Human == 1:
        if icon == "X":
            number = 1
            print("Your turn player {}".format(number))
            choice = int(input("Enter your move (1-9): ").strip())
            
            if board[choice - 1] == " ":
                board[choice - 1] = icon
                choices_made.append(choice)
            
            else:
                print()
                print("That space is taken!")
                player_move(icon)
        
        elif icon == "O":
            choices_possible = uncommon_items(choices_range,choices_made)
            rand_idx = random.randrange(len(choices_possible))
            random_num = choices_possible[rand_idx]
            choice = random_num
            board[choice - 1] = icon
            choices_made.append(choice)
            
def is_victory(icon):
    if (board[0] == icon and board[1] == icon and board[2] == icon) or \
    (board[3] == icon and board[4] == icon and board[5] == icon) or \
    (board[6] == icon and board[7] == icon and board[8] == icon) or \
    (board[0] == icon and board[3] == icon and board[6] == icon) or \
    (board[1] == icon and board[4] == icon and board[7] == icon) or \
    (board[2] == icon and board[5] == icon and board[8] == icon) or \
    (board[0] == icon and board[4] == icon and board[8] == icon) or \
    (board[2] == icon and board[4] == icon and board[6] == icon):
        return True
    
    else:
        return False
    
def is_draw():
    if " " not in board:
        return True
    
    else:
        return False

def uncommon_items(list1, list2):
                out = [item for item in list1 if not item in list2]
                return out

while True:
    
    import random
    newboard = [" " for x in range(9)]
    board = newboard
    choices_made = []
    choices_range = [1,2,3,4,5,6,7,8,9]
    AI_Human= int(input("Single player tape:1, 2 players tape:2 "))
    
    while True:
        print_board()
        player_move("X")
        print_board()
        
        if is_victory("X"):
            print("X wins! Congratulations!")
            break
        
        elif is_draw():
            print("It's a draw!")
            break
        
        player_move("O")
        
        if is_victory("O"):
            print_board()
            print("O wins! Congratulations!")
            break
        
        elif is_draw():
            print("It's a draw!")
            break
    
    restart = input("Do you want to play ? (yes/no): ")
    if restart.lower() != "yes":
        break
